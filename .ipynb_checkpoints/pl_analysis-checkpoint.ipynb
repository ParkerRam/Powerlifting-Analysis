# %% [markdown]
# ## Introduction
#
# Powerlifting is a strength sport that revolves around three maximal attempts of the squat, bench and deadlift.

# %% [markdown]
# ## About the Dataset

# %% [markdown]
# ## 1. Imports

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
import sklearn as sk

pd.set_option('display.max_columns', 500)

# %% [markdown]
# ## 2. Reading/Preparing the Data

# %%
pl = pd.read_csv("openpowerlifting.csv")
print(pl.shape)
pl.head(n=5)
# Out:
# (911485, 36)
#                Name Sex Event   Equipment   Age     Division  BodyweightKg  \
# 0  Angie Belk Terry   F   SBD       Wraps  47.0    Mst 45-49         59.60
# 1       Dawn Bogart   F   SBD  Single-ply  42.0    Mst 40-44         58.51
# 2       Dawn Bogart   F   SBD  Single-ply  42.0  Open Senior         58.51
# 3       Dawn Bogart   F     B         Raw  42.0  Open Senior         58.51
# 4      Destiny Dula   F    BD         Raw  18.0   Teen 18-19         63.68
#
#   WeightClassKg  Squat1Kg  Squat2Kg  Squat3Kg  Squat4Kg  Best3SquatKg  \
# 0            60     38.56     47.63    -54.43       NaN         47.63
# 1            60    120.20    136.08    142.88       NaN        142.88
# 2            60    120.20    136.08    142.88       NaN        142.88
# 3            60       NaN       NaN       NaN       NaN           NaN
# 4          67.5       NaN       NaN       NaN       NaN           NaN
#
#    Bench1Kg  Bench2Kg  Bench3Kg  Bench4Kg  Best3BenchKg  Deadlift1Kg  \
# 0     15.88     20.41    -24.95       NaN         20.41        61.23
# 1     88.45     95.25    -97.52       NaN         95.25       136.08
# 2     88.45     95.25    -97.52       NaN         95.25       136.08
# 3     88.45     95.25    -97.52       NaN         95.25          NaN
# 4     29.48     31.75    -34.02       NaN         31.75        90.72
#
#    Deadlift2Kg  Deadlift3Kg  Deadlift4Kg  Best3DeadliftKg  TotalKg Place  \
# 0        70.31       -77.11          NaN            70.31   138.35     1
# 1       149.69       163.29          NaN           163.29   401.42     1
# 2       149.69       163.29          NaN           163.29   401.42     1
# 3          NaN          NaN          NaN              NaN    95.25     1
# 4       -97.52          NaN          NaN            90.72   122.47     1
#
#     Wilks  McCulloch Tested AgeClass Country  Glossbrenner Federation  \
# 0  155.05     167.76     No    45-49     NaN        137.00  365Strong
# 1  456.38     465.50     No    40-44     NaN        403.37  365Strong
# 2  456.38     465.50     No    40-44     NaN        403.37  365Strong
# 3  108.29     110.46     No    40-44     NaN         95.71  365Strong
# 4  130.47     138.29     No    18-19     NaN        115.19  365Strong
#
#          Date MeetCountry MeetState  \
# 0  2016-10-29         USA        NC
# 1  2016-10-29         USA        NC
# 2  2016-10-29         USA        NC
# 3  2016-10-29         USA        NC
# 4  2016-10-29         USA        NC
#
#                                             MeetName
# 0  Junior & Senior National Powerlifting Champion...
# 1  Junior & Senior National Powerlifting Champion...
# 2  Junior & Senior National Powerlifting Champion...
# 3  Junior & Senior National Powerlifting Champion...
# 4  Junior & Senior National Powerlifting Champion...

# %% [markdown]
# We can see that we have quite a few irrelevant columns for the purpose of our analysis, so let's clean it up a bit. Additionally, we'll only be analysing 'SBD' events as that is what I'm most interested in.

# %%
pl = pl.drop(['MeetName', 'Country', 'Squat1Kg', 'Squat2Kg', 'Squat3Kg', 'Squat4Kg', 'Bench1Kg', 'Bench2Kg',
              'Bench3Kg', 'Bench4Kg', 'Deadlift1Kg', 'Deadlift2Kg', 'Deadlift3Kg', 'Deadlift4Kg', 'AgeClass', 'McCulloch', 
              'Glossbrenner', 'Division'], axis=1)
pl = pl[pl['Event'] == 'SBD']
pl = pl[pl['Equipment'] == 'Raw']
pl.head(n=5)
# Out:
#               Name Sex Event Equipment   Age  BodyweightKg WeightClassKg  \
# 6    Maureen Clary   F   SBD       Raw  60.0         67.31          67.5
# 7    Maureen Clary   F   SBD       Raw  60.0         67.31          67.5
# 14  Danielle Ortiz   F   SBD       Raw  17.0         69.31            75
# 17       Emma Love   F   SBD       Raw  18.0         77.93          82.5
# 18    Kelly Benson   F   SBD       Raw  22.0         88.72            90
#
#     Best3SquatKg  Best3BenchKg  Best3DeadliftKg  TotalKg Place   Wilks Tested  \
# 6         124.74         95.25           163.29   383.28     1  391.98     No
# 7         124.74         95.25           163.29   383.28     1  391.98     No
# 14         81.65         49.90           115.67   247.22     1  247.64     No
# 17         86.18         52.16            83.91   222.25     1  206.43     No
# 18        102.06         77.11           120.20   299.37     1  260.25     No
#
#    Federation        Date MeetCountry MeetState
# 6   365Strong  2016-10-29         USA        NC
# 7   365Strong  2016-10-29         USA        NC
# 14  365Strong  2016-10-29         USA        NC
# 17  365Strong  2016-10-29         USA        NC
# 18  365Strong  2016-10-29         USA        NC

# %% [markdown]
# We'll take care of NaN values so our data fits the criteria that the lifter's
# * Age was included
# * Weight was included
# * Whether or not was tested
# * Didn't bomb
# * Wilks was included
# * Competed raw
# * Competed in full power meet (SBD)
#
# Also we will mutate the date column to include just the year.

# %%
pl = pl.dropna(subset = ['BodyweightKg', 'Best3SquatKg', 'Best3BenchKg', 'Best3DeadliftKg','TotalKg', 'Wilks', 
                         'Tested', 'Age'])
pl['Year'] = pd.DatetimeIndex(pl['Date']).year  
pl = pl.drop(['Date'], axis=1)
print(pl.shape)
pl.head(n=5)
# Out:
# (176436, 18)
#               Name Sex Event Equipment   Age  BodyweightKg WeightClassKg  \
# 6    Maureen Clary   F   SBD       Raw  60.0         67.31          67.5
# 7    Maureen Clary   F   SBD       Raw  60.0         67.31          67.5
# 14  Danielle Ortiz   F   SBD       Raw  17.0         69.31            75
# 17       Emma Love   F   SBD       Raw  18.0         77.93          82.5
# 18    Kelly Benson   F   SBD       Raw  22.0         88.72            90
#
#     Best3SquatKg  Best3BenchKg  Best3DeadliftKg  TotalKg Place   Wilks Tested  \
# 6         124.74         95.25           163.29   383.28     1  391.98     No
# 7         124.74         95.25           163.29   383.28     1  391.98     No
# 14         81.65         49.90           115.67   247.22     1  247.64     No
# 17         86.18         52.16            83.91   222.25     1  206.43     No
# 18        102.06         77.11           120.20   299.37     1  260.25     No
#
#    Federation MeetCountry MeetState  Year
# 6   365Strong         USA        NC  2016
# 7   365Strong         USA        NC  2016
# 14  365Strong         USA        NC  2016
# 17  365Strong         USA        NC  2016
# 18  365Strong         USA        NC  2016

# %% [markdown]
# ## 3. Gender Analysis

# %% [markdown]
# The sport is dominated by males so let's see what proportion are females and males.

# %%
print('Percentage of Male lifters: ', round(len(pl[pl['Sex']=='M'])/len(pl)*100),'%')
print('Percentage of Female lifters: ', round(len(pl[pl['Sex']=='F'])/len(pl)*100),'%')
# Out:
# Percentage of Male lifters:  66 %
# Percentage of Female lifters:  34 %

# %% [markdown]
# Let's take a look at the growth of the sport grouped by gender. We will first mutate the date column to be just the year.

# %%
pl.groupby(by=['Sex','Year']).count();

mf = sns.FacetGrid(data=pl, hue='Sex', height=6, aspect=2, legend_out=True, palette="Set1")
mf = mf.map(plt.plot, 'Year', 'Name')
plt.legend(loc=1, title="Sex")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-193-cd69dc3d04bf> in <module>
#       2
#       3 mf = sns.FacetGrid(data=pl, hue='Sex', height=6, aspect=2, legend_out=True, palette="Set1")
# ----> 4 mf = mf.map(plt.plot, 'Year', 'Name')
#       5 plt.legend(loc=1, title="Sex")
#       6 plt.show()
#
# /anaconda3/lib/python3.7/site-packages/seaborn/axisgrid.py in map(self, func, *args, **kwargs)
#     755
#     756         # Finalize the annotations and layout
# --> 757         self._finalize_grid(args[:2])
#     758
#     759         return self
#
# /anaconda3/lib/python3.7/site-packages/seaborn/axisgrid.py in _finalize_grid(self, axlabels)
#     846         self.set_axis_labels(*axlabels)
#     847         self.set_titles()
# --> 848         self.fig.tight_layout()
#     849
#     850     def facet_axis(self, row_i, col_j):
#
# /anaconda3/lib/python3.7/site-packages/matplotlib/figure.py in tight_layout(self, renderer, pad, h_pad, w_pad, rect)
#    2372         kwargs = get_tight_layout_figure(
#    2373             self, self.axes, subplotspec_list, renderer,
# -> 2374             pad=pad, h_pad=h_pad, w_pad=w_pad, rect=rect)
#    2375         if kwargs:
#    2376             self.subplots_adjust(**kwargs)
#
# /anaconda3/lib/python3.7/site-packages/matplotlib/tight_layout.py in get_tight_layout_figure(fig, axes_list, subplotspec_list, renderer, pad, h_pad, w_pad, rect)
#     364                                      subplot_list=subplot_list,
#     365                                      ax_bbox_list=ax_bbox_list,
# --> 366                                      pad=pad, h_pad=h_pad, w_pad=w_pad)
#     367
#     368     if rect is not None:
#
# /anaconda3/lib/python3.7/site-packages/matplotlib/tight_layout.py in auto_adjust_subplotpars(fig, renderer, nrows_ncols, num1num2_list, subplot_list, ax_bbox_list, pad, h_pad, w_pad, rect)
#     113             continue
#     114
# --> 115         tight_bbox_raw = union([ax.get_tightbbox(renderer) for ax in subplots
#     116                                 if ax.get_visible()])
#     117         tight_bbox = TransformedBbox(tight_bbox_raw,
#
# /anaconda3/lib/python3.7/site-packages/matplotlib/tight_layout.py in <listcomp>(.0)
#     114
#     115         tight_bbox_raw = union([ax.get_tightbbox(renderer) for ax in subplots
# --> 116                                 if ax.get_visible()])
#     117         tight_bbox = TransformedBbox(tight_bbox_raw,
#     118                                      fig.transFigure.inverted())
#
# /anaconda3/lib/python3.7/site-packages/matplotlib/axes/_base.py in get_tightbbox(self, renderer, call_axes_locator, bbox_extra_artists)
#    4385             bb.append(self._right_title.get_window_extent(renderer))
#    4386
# -> 4387         bb_yaxis = self.yaxis.get_tightbbox(renderer)
#    4388         if bb_yaxis:
#    4389             bb.append(bb_yaxis)
#
# /anaconda3/lib/python3.7/site-packages/matplotlib/axis.py in get_tightbbox(self, renderer)
#    1138             return
#    1139
# -> 1140         ticks_to_draw = self._update_ticks(renderer)
#    1141
#    1142         self._update_label_position(renderer)
#
# /anaconda3/lib/python3.7/site-packages/matplotlib/axis.py in _update_ticks(self, renderer)
#    1021
#    1022         interval = self.get_view_interval()
# -> 1023         tick_tups = list(self.iter_ticks())  # iter_ticks calls the locator
#    1024         if self._smart_bounds and tick_tups:
#    1025             # handle inverted limits
#
# /anaconda3/lib/python3.7/site-packages/matplotlib/axis.py in iter_ticks(self)
#     969         self.major.formatter.set_locs(majorLocs)
#     970         majorLabels = [self.major.formatter(val, i)
# --> 971                        for i, val in enumerate(majorLocs)]
#     972
#     973         minorLocs = self.minor.locator()
#
# /anaconda3/lib/python3.7/site-packages/matplotlib/axis.py in <listcomp>(.0)
#     969         self.major.formatter.set_locs(majorLocs)
#     970         majorLabels = [self.major.formatter(val, i)
# --> 971                        for i, val in enumerate(majorLocs)]
#     972
#     973         minorLocs = self.minor.locator()
#
# /anaconda3/lib/python3.7/site-packages/matplotlib/category.py in __call__(self, x, pos)
#     140             return ""
#     141         r_mapping = {v: StrCategoryFormatter._text(k)
# --> 142                      for k, v in self._units.items()}
#     143         return r_mapping.get(int(np.round(x)), '')
#     144
#
# /anaconda3/lib/python3.7/site-packages/matplotlib/category.py in <dictcomp>(.0)
#     140             return ""
#     141         r_mapping = {v: StrCategoryFormatter._text(k)
# --> 142                      for k, v in self._units.items()}
#     143         return r_mapping.get(int(np.round(x)), '')
#     144
#
# KeyboardInterrupt:

# %% [markdown]
# ## 4. Test vs. Non-tested

# %% [markdown]
# First let's see the distribution of tested and non-tested lifters, we will also group by gender as this is most likely another strong confounding variable. In this context tested (1) means the lifter is subject to drug testing but this does not necessarily mean the lifter is tested.
#
# Wilks is a point system based on the total weight lifted and the lifter's bodyweight (higher is better).

# %%
print(pl['Tested'].value_counts())
# Out:
# Yes    127923
# No      48513
# Name: Tested, dtype: int64

# %%
g = sns.FacetGrid(data=pl, hue='Tested', row='Sex', height=6, aspect=2, legend_out=True, palette="Set1")
g = g.map(plt.hist, 'Wilks', bins=20, alpha=0.6)
plt.yticks(fontsize=15)
plt.xticks(fontsize=15)
plt.xlabel('Wilks',fontsize=15)
plt.legend(loc=1, title="Tested")
plt.show()

print("MEAN \n", pl.groupby(by=['Tested','Sex'])['Wilks'].mean())
print("\n\nMEDIAN \n", pl.groupby(by=['Tested','Sex'])['Wilks'].median())
print("\n\nMAX \n", pl.groupby(by=['Tested','Sex'])['Wilks'].max())
# Out:
# MEAN
#  Tested  Sex
# No      F      313.820438
#         M      362.684352
# Yes     F      314.340158
#         M      354.303991
# Name: Wilks, dtype: float64
#
#
# MEDIAN
#  Tested  Sex
# No      F      311.590
#         M      363.910
# Yes     F      312.815
#         M      356.630
# Name: Wilks, dtype: float64
#
#
# MAX
#  Tested  Sex
# No      F      634.84
#         M      601.50
# Yes     F      558.86
#         M      597.23
# Name: Wilks, dtype: float64

# %% [markdown]
# Here we can see that other from amount of people in each group the two distributions are relatively the same. The mean, median and max are slightly higher for the non-tested group which may be explained by drug use.
